# %%
class Queue:
    def __init__(self):
        self.data = [] #Lista vacia
    
    def is_empty(self):
        return len(self.data) == 0 

    def length(self):
        return len(self.data)

    def enqueue(self, value):
        self.data.append(value) #Agregas valor a la Q 

    def dequeue(self, value):    #Quita un valor de la Q
        return self.data.pop(0)  # "0" es el primer valor de la linea

    def to_string(self):
        for elem in self.data:
            print(f"| {elem} | <--", end= "")
        print("")

# %%
cola = Queue()
print("Esta vacio??: " , cola.is_empty())
print("Numero de elementos = " , cola.length() )
cola.enqueue(10)
cola.enqueue(20)
cola.enqueue(30)

print("Esta vacio??: " , cola.is_empty())
print("Numero de elementos = " , cola.length() )
cola.enqueue(40)
cola.enqueue(50)
cola.enqueue(60)
cola.to_string()

siguiente = cola.dequeue(0)
print("Atendiendo a:" , siguiente)
cola.to_string()
# Out:
# Esta vacio??:  True
# Numero de elementos =  0
# Esta vacio??:  False
# Numero de elementos =  3
# | 10 | <--| 20 | <--| 30 | <--| 40 | <--| 50 | <--| 60 | <--
# Atendiendo a: 10
# | 20 | <--| 30 | <--| 40 | <--| 50 | <--| 60 | <--

# %% [markdown]
# #Variantes del ADT Queue
# 1. Circulares
# 2. Prioridad
#     * Acotada
#     * No acotada
